# %%
import pandas as pd
import numpy as np
import re

# %%
# import csv file and create dataframe as df
df=pd.read_csv('full_data_cleaning_practice_dataset.csv').copy()

# %%
df.head(3)
# top 3 rows
# Out:
#    order_id customer_name  customer_age        email       phone  order_date  \
# 0    1072.0         sara          200.0         abc@       12345  13-04-2023
# 1    1016.0         RAHUL           NaN  user@domain    99999abc  2024.03.11
# 2    1008.0           NaN         200.0         abc@  9876543210  2023/09/28
#
#   shipping_date     city       state  sales_amount  quantity  \
# 0    2024.07.09      NaN  Tamil Nadu     9999999.0       NaN
# 1    03-11-2024    PUNE        Delhi     9999999.0       5.0
# 2    01/20/2024  Chennai       Delhi         500.0      -1.0
#
#    discount_percent payment_mode is_returned product_category
# 0              10.0          NaN           Y         Clothing
# 1               NaN          NaN         NaN     electronics
# 2               NaN   NetBanking         Yes              NaN

# %%
df.info()
# dataframe information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1038 non-null   float64
#  1   customer_name     832 non-null    object
#  2   customer_age      871 non-null    float64
#  3   email             808 non-null    object
#  4   phone             779 non-null    object
#  5   order_date        1050 non-null   object
#  6   shipping_date     1049 non-null   object
#  7   city              844 non-null    object
#  8   state             797 non-null    object
#  9   sales_amount      888 non-null    float64
#  10  quantity          873 non-null    float64
#  11  discount_percent  838 non-null    float64
#  12  payment_mode      821 non-null    object
#  13  is_returned       820 non-null    object
#  14  product_category  840 non-null    object
# dtypes: float64(5), object(10)
# memory usage: 123.2+ KB

# %%
df.duplicated().sum()
# sum of duplicates
# Out:
# np.int64(50)

# %%
df=df.drop_duplicates()
# drop duplicates

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          990 non-null    float64
#  1   customer_name     790 non-null    object
#  2   customer_age      835 non-null    float64
#  3   email             769 non-null    object
#  4   phone             743 non-null    object
#  5   order_date        1000 non-null   object
#  6   shipping_date     999 non-null    object
#  7   city              802 non-null    object
#  8   state             758 non-null    object
#  9   sales_amount      845 non-null    float64
#  10  quantity          832 non-null    float64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# dtypes: float64(5), object(10)
# memory usage: 125.0+ KB

# %%
df.duplicated(subset='order_id').sum()
# sum of order_id column duplicates
# Out:
# np.int64(899)

# %%
df.loc[df['order_id']==1002]
# 1002 Order_Id Total Rows check
# Out:
#      order_id customer_name  customer_age           email       phone  \
# 262    1002.0         sara           -5.0             NaN         NaN
# 445    1002.0         sara           30.0            abc@    99999abc
# 520    1002.0         Anita          35.0            abc@       12345
# 567    1002.0           NaN          30.0     user@domain         NaN
# 616    1002.0         RAHUL          30.0             NaN    99999abc
# 634    1002.0          Amit          25.0  test@gmail.com  9876543210
# 837    1002.0          Amit          -5.0     user@domain         NaN
# 866    1002.0         Anita          35.0            abc@    99999abc
# 873    1002.0           NaN          -5.0  test@gmail.com  9876543210
# 976    1002.0         Anita          -5.0     user@domain  9876543210
#
#      order_date shipping_date     city        state  sales_amount  quantity  \
# 262  02-09-2024    29-09-2024  Chennai  Maharashtra           NaN       5.0
# ...

# %%
df = df.reset_index(drop=True)
# drop all indexes
df['order_id'] = np.arange(1000, 1000 + len(df))
# New Order id 1000 to 2000

# %%
df['order_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['order_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['order_id']=df['order_id'].astype(int)
# type float to integer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     790 non-null    object
#  2   customer_age      835 non-null    float64
#  3   email             769 non-null    object
#  4   phone             743 non-null    object
#  5   order_date        1000 non-null   object
#  6   shipping_date     999 non-null    object
#  7   city              802 non-null    object
#  8   state             758 non-null    object
#  9   sales_amount      845 non-null    float64
#  10  quantity          832 non-null    float64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 117.3+ KB

# %%
df['customer_name'].isnull().sum()
# Out:
# np.int64(210)

# %%
df['customer_name']=df['customer_name'].str.strip().str.title()
# space remove and first letter capital

# %%
df['customer_name']=df['customer_name'].fillna('Unknown')
# fill NaN to 'Unknown'

# %%
df.head()
# Out:
#    order_id customer_name  customer_age        email       phone  order_date  \
# 0      1000          Sara         200.0         abc@       12345  13-04-2023
# 1      1001         Rahul           NaN  user@domain    99999abc  2024.03.11
# 2      1002       Unknown         200.0         abc@  9876543210  2023/09/28
# 3      1003          Amit          30.0  user@domain         NaN  2023-04-17
# 4      1004         Rahul          -5.0  user@domain    99999abc  03/13/2023
#
#   shipping_date     city        state  sales_amount  quantity  \
# 0    2024.07.09      NaN   Tamil Nadu     9999999.0       NaN
# 1    03-11-2024    PUNE         Delhi     9999999.0       5.0
# 2    01/20/2024  Chennai        Delhi         500.0      -1.0
# 3    05/26/2023   mumbai  Maharashtra           NaN       1.0
# 4    2024/06/09  Chennai          NaN        -300.0       2.0
#
#    discount_percent payment_mode is_returned product_category
# 0              10.0          NaN           Y         Clothing
# ...

# %%
df['customer_age'].isnull().sum()
# Out:
# np.int64(165)

# %%
df['customer_age']=df['customer_age'].fillna(0)

# %%
df.loc[(df['customer_age']<1)|(df['customer_age']>100),'customer_age']=0
# Customer age can proceed from 1 to 100. Otherwise proceed from 0.

# %%
df['customer_age']=df['customer_age'].astype(int).copy()
# conver to integer

# %%
df.head()
# Out:
#    order_id customer_name  customer_age        email       phone  order_date  \
# 0      1000          Sara             0         abc@       12345  13-04-2023
# 1      1001         Rahul             0  user@domain    99999abc  2024.03.11
# 2      1002       Unknown             0         abc@  9876543210  2023/09/28
# 3      1003          Amit            30  user@domain         NaN  2023-04-17
# 4      1004         Rahul             0  user@domain    99999abc  03/13/2023
#
#   shipping_date     city        state  sales_amount  quantity  \
# 0    2024.07.09      NaN   Tamil Nadu     9999999.0       NaN
# 1    03-11-2024    PUNE         Delhi     9999999.0       5.0
# 2    01/20/2024  Chennai        Delhi         500.0      -1.0
# 3    05/26/2023   mumbai  Maharashtra           NaN       1.0
# 4    2024/06/09  Chennai          NaN        -300.0       2.0
#
#    discount_percent payment_mode is_returned product_category
# 0              10.0          NaN           Y         Clothing
# ...

# %%
df['email']
# Out:
# 0                abc@
# 1         user@domain
# 2                abc@
# 3         user@domain
# 4         user@domain
#             ...
# 995               NaN
# 996               NaN
# 997    test@gmail.com
# 998    test@gmail.com
# 999    test@gmail.com
# Name: email, Length: 1000, dtype: object

# %%
pattern = r'^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$'
# create email pattern

# %%
df.loc[~df['email'].str.match(pattern, na=False), 'email'] = np.nan
# check email true or not.if not true fill NaN

# %%
df['email'] = df['email'].str.strip().str.lower()
# remove space and convert to lower case

# %%
df['email'] = df['email'].fillna('unknown@email.com')
# Fill in the non-email address with 'unknown@email.com'

# %%
df.head()
# Out:
#    order_id customer_name  customer_age              email       phone  \
# 0      1000          Sara             0  unknown@email.com       12345
# 1      1001         Rahul             0  unknown@email.com    99999abc
# 2      1002       Unknown             0  unknown@email.com  9876543210
# 3      1003          Amit            30  unknown@email.com         NaN
# 4      1004         Rahul             0  unknown@email.com    99999abc
#
#    order_date shipping_date     city        state  sales_amount  quantity  \
# 0  13-04-2023    2024.07.09      NaN   Tamil Nadu     9999999.0       NaN
# 1  2024.03.11    03-11-2024    PUNE         Delhi     9999999.0       5.0
# 2  2023/09/28    01/20/2024  Chennai        Delhi         500.0      -1.0
# 3  2023-04-17    05/26/2023   mumbai  Maharashtra           NaN       1.0
# 4  03/13/2023    2024/06/09  Chennai          NaN        -300.0       2.0
#
#    discount_percent payment_mode is_returned product_category
# ...

# %%
pattern = r'^[0-9]{10}$'

# %%
df.loc[~df['phone'].str.match(pattern, na=False), 'phone'] = np.nan

# %%
df['phone'] = df['phone'].astype('string')

df['phone'] = df['phone'].fillna('unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   object
#  6   shipping_date     999 non-null    object
#  7   city              802 non-null    object
#  8   state             758 non-null    object
#  9   sales_amount      845 non-null    float64
#  10  quantity          832 non-null    float64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# dtypes: float64(3), int64(2), object(9), string(1)
# ...

# %%
df['order_date'] = df['order_date'].str.strip().copy()

# %%
df['order_date'] = df['order_date'].str.replace(r'[/.]', '-', regex=True)
# Replaced '/' and '.' with '-'

# %%
df.head(3)
# Out:
#    order_id customer_name  customer_age              email       phone  \
# 0      1000          Sara             0  unknown@email.com     unknown
# 1      1001         Rahul             0  unknown@email.com     unknown
# 2      1002       Unknown             0  unknown@email.com  9876543210
#
#    order_date shipping_date     city       state  sales_amount  quantity  \
# 0  13-04-2023    2024.07.09      NaN  Tamil Nadu     9999999.0       NaN
# 1  2024-03-11    03-11-2024    PUNE        Delhi     9999999.0       5.0
# 2  2023-09-28    01/20/2024  Chennai       Delhi         500.0      -1.0
#
#    discount_percent payment_mode is_returned product_category
# 0              10.0          NaN           Y         Clothing
# 1               NaN          NaN         NaN     electronics
# 2               NaN   NetBanking         Yes              NaN

# %%
df1=df[['order_id','order_date']].copy()
# Created a new dataframe DF1 and inserted the 'Order_Id' and 'Order_Date' columns from DF

# %%
df2=df[['order_id','order_date']].copy()
# Created a new dataframe DF2 and inserted the 'Order_Id' and 'Order_Date' columns from DF

# %%
df1['order_date']=df1['order_date'].str.strip()

# %%
df2['order_date']=df2['order_date'].str.strip()

# %%
df1
# Out:
#      order_id  order_date
# 0        1000  13-04-2023
# 1        1001  2024-03-11
# 2        1002  2023-09-28
# 3        1003  2023-04-17
# 4        1004  03-13-2023
# ..        ...         ...
# 995      1995  2024-10-03
# 996      1996  18-08-2024
# 997      1997  2023-11-17
# 998      1998  2023-11-15
# 999      1999  2024-09-04
#
# [1000 rows x 2 columns]

# %%
df2
# Out:
#      order_id  order_date
# 0        1000  13-04-2023
# 1        1001  2024-03-11
# 2        1002  2023-09-28
# 3        1003  2023-04-17
# 4        1004  03-13-2023
# ..        ...         ...
# 995      1995  2024-10-03
# 996      1996  18-08-2024
# 997      1997  2023-11-17
# 998      1998  2023-11-15
# 999      1999  2024-09-04
#
# [1000 rows x 2 columns]

# %%
df2['order_date'] = pd.to_datetime(
    df2['order_date'],
    errors='coerce',
    dayfirst=True
)
# Convert order_date column from object to datetime
# used dayfirst=True to handle mixed date formats
# To make invalid dates NaT errors='coerce'

# %%
df2
# Out:
#      order_id order_date
# 0        1000 2023-04-13
# 1        1001        NaT
# 2        1002        NaT
# 3        1003        NaT
# 4        1004        NaT
# ..        ...        ...
# 995      1995        NaT
# 996      1996 2024-08-18
# 997      1997        NaT
# 998      1998        NaT
# 999      1999        NaT
#
# [1000 rows x 2 columns]

# %%
df1['order_date'] = pd.to_datetime(
    df1['order_date'].astype(str).str.strip(),
    format='%Y-%m-%d',
    errors='coerce'
)
# Convert order_date column from object to datetime
# used format='%Y-%m-%d' to handle mixed date formats
# To make invalid dates NaT errors='coerce'

# %%
df1
# Out:
#      order_id order_date
# 0        1000        NaT
# 1        1001 2024-03-11
# 2        1002 2023-09-28
# 3        1003 2023-04-17
# 4        1004        NaT
# ..        ...        ...
# 995      1995 2024-10-03
# 996      1996        NaT
# 997      1997 2023-11-17
# 998      1998 2023-11-15
# 999      1999 2024-09-04
#
# [1000 rows x 2 columns]

# %%
df3 = (
    df1.merge(df2, on='order_id', how='outer', suffixes=('_df1', '_df2'))
       .assign(order_date=lambda x: x['order_date_df1'].combine_first(x['order_date_df2']))
       .drop(columns=['order_date_df1', 'order_date_df2'])
)
# Merge df1 and df2 on 'order_id' using outer join
# Create single 'order_date' column by taking df1 date first,
# and filling missing (NaT) values from df2
# Remove temporary date columns after merge

# %%
df3
# Out:
#      order_id order_date
# 0        1000 2023-04-13
# 1        1001 2024-03-11
# 2        1002 2023-09-28
# 3        1003 2023-04-17
# 4        1004        NaT
# ..        ...        ...
# 995      1995 2024-10-03
# 996      1996 2024-08-18
# 997      1997 2023-11-17
# 998      1998 2023-11-15
# 999      1999 2024-09-04
#
# [1000 rows x 2 columns]

# %%
df3['order_date'].isnull().sum()
# Out:
# np.int64(143)

# %%
df3['order_date']=df3['order_date'].fillna('2000-01-01')

# %%
df3
# Out:
#      order_id order_date
# 0        1000 2023-04-13
# 1        1001 2024-03-11
# 2        1002 2023-09-28
# 3        1003 2023-04-17
# 4        1004 2000-01-01
# ..        ...        ...
# 995      1995 2024-10-03
# 996      1996 2024-08-18
# 997      1997 2023-11-17
# 998      1998 2023-11-15
# 999      1999 2024-09-04
#
# [1000 rows x 2 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    1000 non-null   int64
#  1   order_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 15.8 KB

# %%
df['order_date'] = df3['order_date']
# Replace df's order_date column with cleaned/merged order_date from df3

# %%
df
# Out:
#      order_id customer_name  customer_age              email       phone  \
# 0        1000          Sara             0  unknown@email.com     unknown
# 1        1001         Rahul             0  unknown@email.com     unknown
# 2        1002       Unknown             0  unknown@email.com  9876543210
# 3        1003          Amit            30  unknown@email.com     unknown
# 4        1004         Rahul             0  unknown@email.com     unknown
# ..        ...           ...           ...                ...         ...
# 995      1995         Anita            30  unknown@email.com     unknown
# 996      1996         Rahul             0  unknown@email.com     unknown
# 997      1997          Amit            30     test@gmail.com     unknown
# 998      1998       Unknown             0     test@gmail.com     unknown
# 999      1999       Unknown             0     test@gmail.com     unknown
#
#     order_date shipping_date     city        state  sales_amount  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     999 non-null    object
#  7   city              802 non-null    object
#  8   state             758 non-null    object
#  9   sales_amount      845 non-null    float64
#  10  quantity          832 non-null    float64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# ...

# %%
# Like Shame Order_Date
df['shipping_date'] = df['shipping_date'].str.strip()

# %%
df['shipping_date'] = df['shipping_date'].str.replace(r'[/.]', '-', regex=True)

# %%
df_shipping_date_1=df[['order_id','shipping_date']].copy()

# %%
df_shipping_date_2=df[['order_id','shipping_date']].copy()

# %%
df_shipping_date_1['shipping_date'] = df_shipping_date_1['shipping_date'].str.strip()

# %%
df_shipping_date_2['shipping_date'] = df_shipping_date_2['shipping_date'].str.strip()

# %%
df_shipping_date_1
# Out:
#      order_id shipping_date
# 0        1000    2024-07-09
# 1        1001    03-11-2024
# 2        1002    01-20-2024
# 3        1003    05-26-2023
# 4        1004    2024-06-09
# ..        ...           ...
# 995      1995    10-10-2023
# 996      1996    03-08-2024
# 997      1997    2023-08-13
# 998      1998    2024-02-26
# 999      1999    2023-03-31
#
# [1000 rows x 2 columns]

# %%
df_shipping_date_2
# Out:
#      order_id shipping_date
# 0        1000    2024-07-09
# 1        1001    03-11-2024
# 2        1002    01-20-2024
# 3        1003    05-26-2023
# 4        1004    2024-06-09
# ..        ...           ...
# 995      1995    10-10-2023
# 996      1996    03-08-2024
# 997      1997    2023-08-13
# 998      1998    2024-02-26
# 999      1999    2023-03-31
#
# [1000 rows x 2 columns]

# %%
df_shipping_date_2['shipping_date'] = pd.to_datetime(
    df_shipping_date_2['shipping_date'],
    format='%m-%d-%Y',
    errors='coerce'
)
# Convert shipping_date from object to datetime using MM-DD-YYYY format
# Invalid date values will be converted to NaT

# %%
df_shipping_date_2
# Out:
#      order_id shipping_date
# 0        1000           NaT
# 1        1001    2024-03-11
# 2        1002    2024-01-20
# 3        1003    2023-05-26
# 4        1004           NaT
# ..        ...           ...
# 995      1995    2023-10-10
# 996      1996    2024-03-08
# 997      1997           NaT
# 998      1998           NaT
# 999      1999           NaT
#
# [1000 rows x 2 columns]

# %%
df_shipping_date_1['shipping_date'] = pd.to_datetime(
    df_shipping_date_1['shipping_date'].astype(str).str.strip(),
    format='%Y-%m-%d',
    errors='coerce'
)

# %%
df_shipping_date_1
# Out:
#      order_id shipping_date
# 0        1000    2024-07-09
# 1        1001           NaT
# 2        1002           NaT
# 3        1003           NaT
# 4        1004    2024-06-09
# ..        ...           ...
# 995      1995           NaT
# 996      1996           NaT
# 997      1997    2023-08-13
# 998      1998    2024-02-26
# 999      1999    2023-03-31
#
# [1000 rows x 2 columns]

# %%
df_shipping_date_3 = (
    df_shipping_date_1.merge(df_shipping_date_2, on='order_id', how='outer', suffixes=('_df1', '_df2'))
       .assign(shipping_date=lambda x: x['shipping_date_df1'].combine_first(x['shipping_date_df2']))
       .drop(columns=['shipping_date_df1', 'shipping_date_df2'])
)

# %%
df_shipping_date_3
# Out:
#      order_id shipping_date
# 0        1000    2024-07-09
# 1        1001    2024-03-11
# 2        1002    2024-01-20
# 3        1003    2023-05-26
# 4        1004    2024-06-09
# ..        ...           ...
# 995      1995    2023-10-10
# 996      1996    2024-03-08
# 997      1997    2023-08-13
# 998      1998    2024-02-26
# 999      1999    2023-03-31
#
# [1000 rows x 2 columns]

# %%
df_shipping_date_3['shipping_date'].isnull().sum()
# Out:
# np.int64(135)

# %%
df_shipping_date_3['shipping_date']=df_shipping_date_3['shipping_date'].fillna('2000-01-01')

# %%
df_shipping_date_3
# Out:
#      order_id shipping_date
# 0        1000    2024-07-09
# 1        1001    2024-03-11
# 2        1002    2024-01-20
# 3        1003    2023-05-26
# 4        1004    2024-06-09
# ..        ...           ...
# 995      1995    2023-10-10
# 996      1996    2024-03-08
# 997      1997    2023-08-13
# 998      1998    2024-02-26
# 999      1999    2023-03-31
#
# [1000 rows x 2 columns]

# %%
df['shipping_date'] = df_shipping_date_3['shipping_date']

# %%
df
# Out:
#      order_id customer_name  customer_age              email       phone  \
# 0        1000          Sara             0  unknown@email.com     unknown
# 1        1001         Rahul             0  unknown@email.com     unknown
# 2        1002       Unknown             0  unknown@email.com  9876543210
# 3        1003          Amit            30  unknown@email.com     unknown
# 4        1004         Rahul             0  unknown@email.com     unknown
# ..        ...           ...           ...                ...         ...
# 995      1995         Anita            30  unknown@email.com     unknown
# 996      1996         Rahul             0  unknown@email.com     unknown
# 997      1997          Amit            30     test@gmail.com     unknown
# 998      1998       Unknown             0     test@gmail.com     unknown
# 999      1999       Unknown             0     test@gmail.com     unknown
#
#     order_date shipping_date     city        state  sales_amount  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              802 non-null    object
#  8   state             758 non-null    object
#  9   sales_amount      845 non-null    float64
#  10  quantity          832 non-null    float64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# ...

# %%
df['city']=df['city'].str.strip().str.title()

# %%
df['city']=df['city'].fillna('Unknown')

# %%
df['city'].isnull().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      order_id customer_name  customer_age              email       phone  \
# 0        1000          Sara             0  unknown@email.com     unknown
# 1        1001         Rahul             0  unknown@email.com     unknown
# 2        1002       Unknown             0  unknown@email.com  9876543210
# 3        1003          Amit            30  unknown@email.com     unknown
# 4        1004         Rahul             0  unknown@email.com     unknown
# ..        ...           ...           ...                ...         ...
# 995      1995         Anita            30  unknown@email.com     unknown
# 996      1996         Rahul             0  unknown@email.com     unknown
# 997      1997          Amit            30     test@gmail.com     unknown
# 998      1998       Unknown             0     test@gmail.com     unknown
# 999      1999       Unknown             0     test@gmail.com     unknown
#
#     order_date shipping_date     city        state  sales_amount  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             758 non-null    object
#  9   sales_amount      845 non-null    float64
#  10  quantity          832 non-null    float64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# ...

# %%
df['state']=df['state'].str.strip().str.title()

# %%
df['state']=df['state'].fillna('Unknown')

# %%
df['state'].isnull().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      order_id customer_name  customer_age              email       phone  \
# 0        1000          Sara             0  unknown@email.com     unknown
# 1        1001         Rahul             0  unknown@email.com     unknown
# 2        1002       Unknown             0  unknown@email.com  9876543210
# 3        1003          Amit            30  unknown@email.com     unknown
# 4        1004         Rahul             0  unknown@email.com     unknown
# ..        ...           ...           ...                ...         ...
# 995      1995         Anita            30  unknown@email.com     unknown
# 996      1996         Rahul             0  unknown@email.com     unknown
# 997      1997          Amit            30     test@gmail.com     unknown
# 998      1998       Unknown             0     test@gmail.com     unknown
# 999      1999       Unknown             0     test@gmail.com     unknown
#
#     order_date shipping_date     city        state  sales_amount  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             1000 non-null   object
#  9   sales_amount      845 non-null    float64
#  10  quantity          832 non-null    float64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# ...

# %%
df.loc[df['sales_amount']<0,'sales_amount']=0

# %%
df['sales_amount']=df['sales_amount'].fillna(0)

# %%
df['sales_amount'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             1000 non-null   object
#  9   sales_amount      1000 non-null   float64
#  10  quantity          832 non-null    float64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# ...

# %%
df.loc[df['quantity']<0,'quantity']=0

# %%
df['quantity']=df['quantity'].fillna(0)

# %%
df['quantity']=df['quantity'].astype(int)

# %%
df
# Out:
#      order_id customer_name  customer_age              email       phone  \
# 0        1000          Sara             0  unknown@email.com     unknown
# 1        1001         Rahul             0  unknown@email.com     unknown
# 2        1002       Unknown             0  unknown@email.com  9876543210
# 3        1003          Amit            30  unknown@email.com     unknown
# 4        1004         Rahul             0  unknown@email.com     unknown
# ..        ...           ...           ...                ...         ...
# 995      1995         Anita            30  unknown@email.com     unknown
# 996      1996         Rahul             0  unknown@email.com     unknown
# 997      1997          Amit            30     test@gmail.com     unknown
# 998      1998       Unknown             0     test@gmail.com     unknown
# 999      1999       Unknown             0     test@gmail.com     unknown
#
#     order_date shipping_date     city        state  sales_amount  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             1000 non-null   object
#  9   sales_amount      1000 non-null   float64
#  10  quantity          1000 non-null   int64
#  11  discount_percent  799 non-null    float64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# ...

# %%
df.loc[df['discount_percent'] > 100, 'discount_percent'] = np.nan
# 'discount_percent' greater than 100 made Naan

# %%
df['discount_percent']=df['discount_percent'].fillna(0)

# %%
df['discount_percent']=df['discount_percent'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             1000 non-null   object
#  9   sales_amount      1000 non-null   float64
#  10  quantity          1000 non-null   int64
#  11  discount_percent  1000 non-null   int64
#  12  payment_mode      784 non-null    object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# ...

# %%
df['payment_mode'].head(50)
# Out:
# 0            NaN
# 1            NaN
# 2     NetBanking
# 3           card
# 4            NaN
# 5           UPI
# 6           card
# 7           card
# 8            NaN
# 9            NaN
# 10           NaN
# 11          UPI
# 12          card
# 13    NetBanking
# 14          UPI
# 15          Cash
# 16           NaN
# 17          card
# 18          UPI
# 19          Cash
# 20          UPI
# 21          UPI
# 22    NetBanking
# 23    NetBanking
# 24          UPI
# 25          Cash
# 26          card
# 27          card
# 28           NaN
# 29           NaN
# 30          card
# 31          UPI
# 32          UPI
# 33    NetBanking
# 34    NetBanking
# 35           NaN
# 36          card
# 37          UPI
# 38          card
# 39          Cash
# 40          card
# 41          Cash
# 42    NetBanking
# 43    NetBanking
# 44           NaN
# 45          card
# 46          card
# 47          Cash
# 48    NetBanking
# 49          Cash
# Name: payment_mode, dtype: object

# %%
df['payment_mode']=df['payment_mode'].str.strip().str.title()

# %%
df['payment_mode']=df['payment_mode'].fillna('Unknown')

# %%
df
# Out:
#      order_id customer_name  customer_age              email       phone  \
# 0        1000          Sara             0  unknown@email.com     unknown
# 1        1001         Rahul             0  unknown@email.com     unknown
# 2        1002       Unknown             0  unknown@email.com  9876543210
# 3        1003          Amit            30  unknown@email.com     unknown
# 4        1004         Rahul             0  unknown@email.com     unknown
# ..        ...           ...           ...                ...         ...
# 995      1995         Anita            30  unknown@email.com     unknown
# 996      1996         Rahul             0  unknown@email.com     unknown
# 997      1997          Amit            30     test@gmail.com     unknown
# 998      1998       Unknown             0     test@gmail.com     unknown
# 999      1999       Unknown             0     test@gmail.com     unknown
#
#     order_date shipping_date     city        state  sales_amount  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             1000 non-null   object
#  9   sales_amount      1000 non-null   float64
#  10  quantity          1000 non-null   int64
#  11  discount_percent  1000 non-null   int64
#  12  payment_mode      1000 non-null   object
#  13  is_returned       781 non-null    object
#  14  product_category  796 non-null    object
# ...

# %%
df['is_returned'].head(50)
# Out:
# 0       Y
# 1     NaN
# 2     Yes
# 3     NaN
# 4       N
# 5     NaN
# 6     Yes
# 7     NaN
# 8       Y
# 9      No
# 10      Y
# 11     No
# 12    NaN
# 13      N
# 14    NaN
# 15    Yes
# 16    NaN
# 17     No
# 18      Y
# 19      N
# 20    NaN
# 21    NaN
# 22      Y
# 23      N
# 24    NaN
# 25    NaN
# 26     No
# 27     No
# 28    Yes
# 29      Y
# 30      N
# 31    NaN
# 32    NaN
# 33    Yes
# 34    NaN
# 35      Y
# 36    Yes
# 37      Y
# 38    Yes
# 39    NaN
# 40    Yes
# 41     No
# 42      N
# 43    NaN
# 44      N
# 45    NaN
# 46      N
# 47     No
# 48      N
# 49    Yes
# Name: is_returned, dtype: object

# %%
df['is_returned']=df['is_returned'].str.strip().str.title()

# %%
df['is_returned']=df['is_returned'].fillna('Unknown')

# %%
df['is_returned']=df['is_returned'].replace('Y','Yes')
# 'Y' convert to 'Yes'

# %%
df['is_returned']=df['is_returned'].replace('N','No')
# 'N' convert to 'No'

# %%
df
# Out:
#      order_id customer_name  customer_age              email       phone  \
# 0        1000          Sara             0  unknown@email.com     unknown
# 1        1001         Rahul             0  unknown@email.com     unknown
# 2        1002       Unknown             0  unknown@email.com  9876543210
# 3        1003          Amit            30  unknown@email.com     unknown
# 4        1004         Rahul             0  unknown@email.com     unknown
# ..        ...           ...           ...                ...         ...
# 995      1995         Anita            30  unknown@email.com     unknown
# 996      1996         Rahul             0  unknown@email.com     unknown
# 997      1997          Amit            30     test@gmail.com     unknown
# 998      1998       Unknown             0     test@gmail.com     unknown
# 999      1999       Unknown             0     test@gmail.com     unknown
#
#     order_date shipping_date     city        state  sales_amount  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             1000 non-null   object
#  9   sales_amount      1000 non-null   float64
#  10  quantity          1000 non-null   int64
#  11  discount_percent  1000 non-null   int64
#  12  payment_mode      1000 non-null   object
#  13  is_returned       1000 non-null   object
#  14  product_category  796 non-null    object
# ...

# %%
df['product_category'].head(50)
# Out:
# 0          Clothing
# 1      electronics
# 2               NaN
# 3           Grocery
# 4       Electronics
# 5           Grocery
# 6               NaN
# 7           Grocery
# 8      electronics
# 9          Clothing
# 10          Grocery
# 11         Clothing
# 12              NaN
# 13         Clothing
# 14          Grocery
# 15          Grocery
# 16      Electronics
# 17          Grocery
# 18         Clothing
# 19      Electronics
# 20          Grocery
# 21          Grocery
# 22              NaN
# 23      Electronics
# 24              NaN
# 25              NaN
# 26              NaN
# 27     electronics
# 28              NaN
# 29         Clothing
# 30          Grocery
# 31     electronics
# 32              NaN
# 33          Grocery
# 34      Electronics
# 35      Electronics
# 36          Grocery
# 37         Clothing
# 38          Grocery
# 39          Grocery
# 40     electronics
# 41      Electronics
# 42      Electronics
# 43              NaN
# 44          Grocery
# ...

# %%
df['product_category']=df['product_category'].str.strip().str.title()

# %%
df['product_category']=df['product_category'].fillna('Unknown')

# %%
df
# Out:
#      order_id customer_name  customer_age              email       phone  \
# 0        1000          Sara             0  unknown@email.com     unknown
# 1        1001         Rahul             0  unknown@email.com     unknown
# 2        1002       Unknown             0  unknown@email.com  9876543210
# 3        1003          Amit            30  unknown@email.com     unknown
# 4        1004         Rahul             0  unknown@email.com     unknown
# ..        ...           ...           ...                ...         ...
# 995      1995         Anita            30  unknown@email.com     unknown
# 996      1996         Rahul             0  unknown@email.com     unknown
# 997      1997          Amit            30     test@gmail.com     unknown
# 998      1998       Unknown             0     test@gmail.com     unknown
# 999      1999       Unknown             0     test@gmail.com     unknown
#
#     order_date shipping_date     city        state  sales_amount  quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             1000 non-null   object
#  9   sales_amount      1000 non-null   float64
#  10  quantity          1000 non-null   int64
#  11  discount_percent  1000 non-null   int64
#  12  payment_mode      1000 non-null   object
#  13  is_returned       1000 non-null   object
#  14  product_category  1000 non-null   object
# ...

# %%
df.isna().sum()
# check all columns none or not none
# Out:
# order_id            0
# customer_name       0
# customer_age        0
# email               0
# phone               0
# order_date          0
# shipping_date       0
# city                0
# state               0
# sales_amount        0
# quantity            0
# discount_percent    0
# payment_mode        0
# is_returned         0
# product_category    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[(df['discount_percent'] < 0) | (df['discount_percent'] > 100)]
# check 0< 'discount_percent'>100
# Out:
# Empty DataFrame
# Columns: [order_id, customer_name, customer_age, email, phone, order_date, shipping_date, city, state, sales_amount, quantity, discount_percent, payment_mode, is_returned, product_category]
# Index: []

# %%
df[df['sales_amount'] < 0]
# check 'sales_amount'>0
# Out:
# Empty DataFrame
# Columns: [order_id, customer_name, customer_age, email, phone, order_date, shipping_date, city, state, sales_amount, quantity, discount_percent, payment_mode, is_returned, product_category]
# Index: []

# %%
df['order_date'].min()
df['order_date'].max()
# Validate date range:
# - Find minimum (earliest) order date
# - Find maximum (latest) order date
# Used to check unrealistic or future dates
# Out:
# Timestamp('2024-12-30 00:00:00')

# %%
df['order_id'].nunique() == len(df)
# check order_id unique or not
# Out:
# True

# %%
df.describe()
# Perform exploratory data analysis (EDA):
# Generate descriptive statistics (count, mean, std, min, max) for numeric columns
df.describe()
df.groupby('city')['sales_amount'].sum().sort_values(ascending=False)
# Aggregate total sales by city and rank cities by highest revenue
# Out:
# city
# Mumbai     420071158.0
# Unknown    380050462.0
# Pune       340049266.0
# Delhi      270058973.0
# Chennai    240051376.0
# Name: sales_amount, dtype: float64

# %%
df['month'] = df['order_date'].dt.to_period('M')
df.groupby('month')['sales_amount'].sum().sort_values(ascending=False)
# Out:
# month
# 2000-01    280036072.0
# 2024-07     90012591.0
# 2024-10     90012391.0
# 2023-09     90011891.0
# 2023-08     90011591.0
# 2024-02     80007992.0
# 2023-01     80005392.0
# 2024-05     70011893.0
# 2024-01     70008093.0
# 2023-04     60010294.0
# 2023-05     60008694.0
# 2024-11     50016595.0
# 2024-04     50013295.0
# 2024-06     50011795.0
# 2023-03     50010995.0
# 2024-08     50008495.0
# 2023-10     50007395.0
# 2023-06     40013996.0
# 2023-12     40013596.0
# 2023-02     40012496.0
# 2024-12     40009796.0
# 2024-09     40009096.0
# 2024-03     30007097.0
# 2023-07     30005097.0
# 2023-11     30004597.0
# Freq: M, Name: sales_amount, dtype: float64

# %%
df.groupby('customer_name')['sales_amount'].sum().sort_values(ascending=False).head()
# Out:
# customer_name
# Unknown    390055461.0
# Anita      360060864.0
# Sara       340056466.0
# Rahul      300051870.0
# Amit       260056574.0
# Name: sales_amount, dtype: float64

# %%
df.info()
df.isna().sum()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_name     1000 non-null   object
#  2   customer_age      1000 non-null   int64
#  3   email             1000 non-null   object
#  4   phone             1000 non-null   string
#  5   order_date        1000 non-null   datetime64[ns]
#  6   shipping_date     1000 non-null   datetime64[ns]
#  7   city              1000 non-null   object
#  8   state             1000 non-null   object
#  9   sales_amount      1000 non-null   float64
#  10  quantity          1000 non-null   int64
#  11  discount_percent  1000 non-null   int64
#  12  payment_mode      1000 non-null   object
#  13  is_returned       1000 non-null   object
#  14  product_category  1000 non-null   object
#  15  month             1000 non-null   period[M]
# ...

# %%
df.to_csv('clean_sales_data.csv')
